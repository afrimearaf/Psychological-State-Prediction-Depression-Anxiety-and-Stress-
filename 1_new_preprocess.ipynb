# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('data_updated.csv')
data.head()
# Out:
#              Timestamp  Age Gender   Education       Living_Area  \
# 0  18/09/2022 19:41:35   26   Male  Bachelor's  Urban(Town,City)
# 1  18/09/2022 20:02:19   23   Male  Bachelor's  Urban(Town,City)
# 2  19/09/2022 12:31:29   23   Male  Bachelor's  Urban(Town,City)
# 3  19/09/2022 12:34:08   23   Male    Master's  Urban(Town,City)
# 4  19/09/2022 12:45:44   24   Male  Bachelor's  Urban(Town,City)
#
#   Marital_Status Family_Type Coronavirus  \
# 0      Unmarried      Single         Yes
# 1      Unmarried      Single         Yes
# 2      Unmarried      Single          No
# 3      Unmarried       Joint         Yes
# 4      Unmarried      Single          No
#
#                                                   1s  \
# 0  Applied to me to some degree, or some of the time
# 1  Applied to me to some degree, or some of the time
# 2                         Did not apply to me at all
# 3  Applied to me to a considerable degree or a go...
# 4  Applied to me to some degree, or some of the time
#
#                                                   2a  ...  \
# 0        Applied to me very much or most of the time  ...
# 1                         Did not apply to me at all  ...
# 2                         Did not apply to me at all  ...
# 3  Applied to me to some degree, or some of the time  ...
# 4  Applied to me to some degree, or some of the time  ...
#
#                                                  12s  \
# 0  Applied to me to some degree, or some of the time
# 1        Applied to me very much or most of the time
# 2                         Did not apply to me at all
# 3        Applied to me very much or most of the time
# 4                         Did not apply to me at all
#
#                                                  13d  \
# 0  Applied to me to a considerable degree or a go...
# 1  Applied to me to some degree, or some of the time
# 2                         Did not apply to me at all
# 3  Applied to me to a considerable degree or a go...
# 4  Applied to me to some degree, or some of the time
#
#                                                  14s  \
# 0                         Did not apply to me at all
# 1  Applied to me to some degree, or some of the time
# 2  Applied to me to some degree, or some of the time
# 3  Applied to me to some degree, or some of the time
# 4                         Did not apply to me at all
#
#                                                  15a  \
# 0                         Did not apply to me at all
# 1  Applied to me to some degree, or some of the time
# 2  Applied to me to some degree, or some of the time
# 3  Applied to me to a considerable degree or a go...
# 4                         Did not apply to me at all
#
#                                                  16d  \
# 0                         Did not apply to me at all
# 1  Applied to me to some degree, or some of the time
# 2                         Did not apply to me at all
# 3  Applied to me to some degree, or some of the time
# 4                         Did not apply to me at all
#
#                                                  17d  \
# 0                         Did not apply to me at all
# 1  Applied to me to some degree, or some of the time
# 2  Applied to me to some degree, or some of the time
# 3  Applied to me to some degree, or some of the time
# 4                         Did not apply to me at all
#
#                                                  18s  \
# 0                         Did not apply to me at all
# 1  Applied to me to a considerable degree or a go...
# 2                         Did not apply to me at all
# 3  Applied to me to a considerable degree or a go...
# 4  Applied to me to some degree, or some of the time
#
#                                                  19a  \
# 0  Applied to me to some degree, or some of the time
# 1  Applied to me to some degree, or some of the time
# 2                         Did not apply to me at all
# 3  Applied to me to some degree, or some of the time
# 4  Applied to me to some degree, or some of the time
#
#                                                  20a  \
# 0  Applied to me to a considerable degree or a go...
# 1  Applied to me to some degree, or some of the time
# 2                         Did not apply to me at all
# 3  Applied to me to a considerable degree or a go...
# 4                         Did not apply to me at all
#
#                                                  21d
# 0        Applied to me very much or most of the time
# 1  Applied to me to a considerable degree or a go...
# 2                         Did not apply to me at all
# 3        Applied to me very much or most of the time
# 4                         Did not apply to me at all
#
# [5 rows x 29 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 29 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Timestamp       333 non-null    object
#  1   Age             333 non-null    int64
#  2   Gender          333 non-null    object
#  3   Education       333 non-null    object
#  4   Living_Area     333 non-null    object
#  5   Marital_Status  333 non-null    object
#  6   Family_Type     333 non-null    object
#  7   Coronavirus     333 non-null    object
#  8   1s              333 non-null    object
#  9   2a              333 non-null    object
#  10  3d              333 non-null    object
#  11  4a              333 non-null    object
#  12  5d              333 non-null    object
#  13  6s              333 non-null    object
#  14  7a              333 non-null    object
#  15  8s              333 non-null    object
#  16  9a              333 non-null    object
#  17  10d             333 non-null    object
#  18  11s             333 non-null    object
#  19  12s             333 non-null    object
#  20  13d             333 non-null    object
#  21  14s             333 non-null    object
#  22  15a             333 non-null    object
#  23  16d             333 non-null    object
#  24  17d             333 non-null    object
#  25  18s             333 non-null    object
#  26  19a             333 non-null    object
#  27  20a             333 non-null    object
#  28  21d             333 non-null    object
# dtypes: int64(1), object(28)
# memory usage: 75.6+ KB

# %%
df = data.dropna(axis = 0)
print(f"Before dropping all NaN values: {data.shape}")
print(f"After dropping all NaN values: {df.shape}")
# Out:
# Before dropping all NaN values: (333, 29)
# After dropping all NaN values: (333, 29)

# %%
dictonary = {
        "1s":{
        "Did not apply to me at all":0,
        "Applied to me to some degree, or some of the time": 1,
        "Applied to me to a considerable degree or a good part of time":2,
        "Applied to me very much or most of the time": 3,
    },
        "2a":{
        "Did not apply to me at all":0,
        "Applied to me to some degree, or some of the time": 1,
        "Applied to me to a considerable degree or a good part of time":2,
        "Applied to me very much or most of the time": 3,
    },
        "3d":{
        "Did not apply to me at all":0,
        "Applied to me to some degree, or some of the time": 1,
        "Applied to me to a considerable degree or a good part of time":2,
        "Applied to me very much or most of the time": 3,
    },
        "4a":{
        "Did not apply to me at all":0,
        "Applied to me to some degree, or some of the time": 1,
        "Applied to me to a considerable degree or a good part of time":2,
        "Applied to me very much or most of the time": 3,
    },
        "5d":{
        "Did not apply to me at all":0,
        "Applied to me to some degree, or some of the time": 1,
        "Applied to me to a considerable degree or a good part of time":2,
        "Applied to me very much or most of the time": 3,
    },
        "6s":{
        "Did not apply to me at all":0,
        "Applied to me to some degree, or some of the time": 1,
        "Applied to me to a considerable degree or a good part of time":2,
        "Applied to me very much or most of the time": 3,
    },
        "7a":{
        "Did not apply to me at all":0,
        "Applied to me to some degree, or some of the time": 1,
        "Applied to me to a considerable degree or a good part of time":2,
        "Applied to me very much or most of the time": 3,
    },
        "8s":{
        "Did not apply to me at all":0,
        "Applied to me to some degree, or some of the time": 1,
        "Applied to me to a considerable degree or a good part of time":2,
        "Applied to me very much or most of the time": 3,
    },
        "9a":{
        "Did not apply to me at all":0,
        "Applied to me to some degree, or some of the time": 1,
        "Applied to me to a considerable degree or a good part of time":2,
        "Applied to me very much or most of the time": 3,
    },
        "10d":{
        "Did not apply to me at all":0,
        "Applied to me to some degree, or some of the time": 1,
        "Applied to me to a considerable degree or a good part of time":2,
        "Applied to me very much or most of the time": 3,
    },
        "11s":{
        "Did not apply to me at all":0,
        "Applied to me to some degree, or some of the time": 1,
        "Applied to me to a considerable degree or a good part of time":2,
        "Applied to me very much or most of the time": 3,
    },
        "12s":{
        "Did not apply to me at all":0,
        "Applied to me to some degree, or some of the time": 1,
        "Applied to me to a considerable degree or a good part of time":2,
        "Applied to me very much or most of the time": 3,
    },
        "13d":{
        "Did not apply to me at all":0,
        "Applied to me to some degree, or some of the time": 1,
        "Applied to me to a considerable degree or a good part of time":2,
        "Applied to me very much or most of the time": 3,
    },
        "14s":{
        "Did not apply to me at all":0,
        "Applied to me to some degree, or some of the time": 1,
        "Applied to me to a considerable degree or a good part of time":2,
        "Applied to me very much or most of the time": 3,
    },
        "15a":{
        "Did not apply to me at all":0,
        "Applied to me to some degree, or some of the time": 1,
        "Applied to me to a considerable degree or a good part of time":2,
        "Applied to me very much or most of the time": 3,
    },
        "16d":{
        "Did not apply to me at all":0,
        "Applied to me to some degree, or some of the time": 1,
        "Applied to me to a considerable degree or a good part of time":2,
        "Applied to me very much or most of the time": 3,
    },
        "17d":{
        "Did not apply to me at all":0,
        "Applied to me to some degree, or some of the time": 1,
        "Applied to me to a considerable degree or a good part of time":2,
        "Applied to me very much or most of the time": 3,
    },
        "18s":{
        "Did not apply to me at all":0,
        "Applied to me to some degree, or some of the time": 1,
        "Applied to me to a considerable degree or a good part of time":2,
        "Applied to me very much or most of the time": 3,
    },
        "19a":{
        "Did not apply to me at all":0,
        "Applied to me to some degree, or some of the time": 1,
        "Applied to me to a considerable degree or a good part of time":2,
        "Applied to me very much or most of the time": 3,
    },
        "20a":{
        "Did not apply to me at all":0,
        "Applied to me to some degree, or some of the time": 1,
        "Applied to me to a considerable degree or a good part of time":2,
        "Applied to me very much or most of the time": 3,
    },
        "21d":{
        "Did not apply to me at all":0,
        "Applied to me to some degree, or some of the time": 1,
        "Applied to me to a considerable degree or a good part of time":2,
        "Applied to me very much or most of the time": 3,
    }
}

# %%
df=df.replace(dictonary)
df.head()
# Out:
#              Timestamp  Age Gender   Education       Living_Area  \
# 0  18/09/2022 19:41:35   26   Male  Bachelor's  Urban(Town,City)
# 1  18/09/2022 20:02:19   23   Male  Bachelor's  Urban(Town,City)
# 2  19/09/2022 12:31:29   23   Male  Bachelor's  Urban(Town,City)
# 3  19/09/2022 12:34:08   23   Male    Master's  Urban(Town,City)
# 4  19/09/2022 12:45:44   24   Male  Bachelor's  Urban(Town,City)
#
#   Marital_Status Family_Type Coronavirus  1s  2a  ...  12s  13d  14s  15a  \
# 0      Unmarried      Single         Yes   1   3  ...    1    2    0    0
# 1      Unmarried      Single         Yes   1   0  ...    3    1    1    1
# 2      Unmarried      Single          No   0   0  ...    0    0    1    1
# 3      Unmarried       Joint         Yes   2   1  ...    3    2    1    2
# 4      Unmarried      Single          No   1   1  ...    0    1    0    0
#
#    16d  17d  18s  19a  20a  21d
# 0    0    0    0    1    2    3
# 1    1    1    2    1    1    2
# 2    0    1    0    0    0    0
# 3    1    1    2    1    2    3
# 4    0    0    1    1    0    0
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 29 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Timestamp       333 non-null    object
#  1   Age             333 non-null    int64
#  2   Gender          333 non-null    object
#  3   Education       333 non-null    object
#  4   Living_Area     333 non-null    object
#  5   Marital_Status  333 non-null    object
#  6   Family_Type     333 non-null    object
#  7   Coronavirus     333 non-null    object
#  8   1s              333 non-null    int64
#  9   2a              333 non-null    int64
#  10  3d              333 non-null    int64
#  11  4a              333 non-null    int64
#  12  5d              333 non-null    int64
#  13  6s              333 non-null    int64
#  14  7a              333 non-null    int64
#  15  8s              333 non-null    int64
#  16  9a              333 non-null    int64
#  17  10d             333 non-null    int64
#  18  11s             333 non-null    int64
#  19  12s             333 non-null    int64
#  20  13d             333 non-null    int64
#  21  14s             333 non-null    int64
#  22  15a             333 non-null    int64
#  23  16d             333 non-null    int64
#  24  17d             333 non-null    int64
#  25  18s             333 non-null    int64
#  26  19a             333 non-null    int64
#  27  20a             333 non-null    int64
#  28  21d             333 non-null    int64
# dtypes: int64(22), object(7)
# memory usage: 75.6+ KB

# %%
depressionQ = df['3d']+df['5d']+df['10d']+df['13d']+df['16d']+df['17d']+df['21d']
anxietyQ = df['2a']+df['4a']+df['7a']+df['9a']+df['15a']+df['19a']+df['20a']
stressQ = df['1s']+df['6s']+df['8s']+df['11s']+df['12s']+df['14s']+df['18s']


df['total_depression'] = depressionQ*2
def depression_condition(x):
    if (x>=0 and x<=9):
        return "0"
    else :
        return "1"

df['depression_state'] = df['total_depression'].apply(depression_condition)


df['total_anxiety'] = anxietyQ*2
def anxiety_condition(x):
    if (x>=0 and x<=7):
        return "0"
    else :
        return "1"

df['anxiety_state'] = df['total_anxiety'].apply(anxiety_condition)


df['total_stress'] = stressQ*2
def stress_condition(x):
    if (x>=0 and x<=14):
        return "0"
    else :
        return "1"

df['stress_state'] = df['total_stress'].apply(stress_condition)

# %%
df.head()
# Out:
#              Timestamp  Age Gender   Education       Living_Area  \
# 0  18/09/2022 19:41:35   26   Male  Bachelor's  Urban(Town,City)
# 1  18/09/2022 20:02:19   23   Male  Bachelor's  Urban(Town,City)
# 2  19/09/2022 12:31:29   23   Male  Bachelor's  Urban(Town,City)
# 3  19/09/2022 12:34:08   23   Male    Master's  Urban(Town,City)
# 4  19/09/2022 12:45:44   24   Male  Bachelor's  Urban(Town,City)
#
#   Marital_Status Family_Type Coronavirus  1s  2a  ...  18s  19a  20a  21d  \
# 0      Unmarried      Single         Yes   1   3  ...    0    1    2    3
# 1      Unmarried      Single         Yes   1   0  ...    2    1    1    2
# 2      Unmarried      Single          No   0   0  ...    0    0    0    0
# 3      Unmarried       Joint         Yes   2   1  ...    2    1    2    3
# 4      Unmarried      Single          No   1   1  ...    1    1    0    0
#
#    total_depression  depression_state  total_anxiety  anxiety_state  \
# 0                18                 1             20              1
# 1                16                 1             18              1
# 2                 4                 0              8              1
# 3                26                 1             26              1
# 4                 6                 0              6              0
#
#    total_stress  stress_state
# 0            12             0
# 1            28             1
# 2             6             0
# 3            32             1
# 4             8             0
#
# [5 rows x 35 columns]

# %%
df.to_csv('data_updated_clean.csv')
